# %%
# %matplotlib inline
from config_calc import *
import grid_tools

import numpy as np
import xarray as xr

from collections import OrderedDict

import cesm_orcas_sci as cesm
import cam
import gv
import metpy.calc as mcalc

import matplotlib.pyplot as plt
import cartopy
import cartopy.crs as ccrs
import matplotlib.pyplot as plt

# %%
# %%time
case = 'bgeos5.B20TRC5CN.f09_g16.BPRD_orcas_sci.004'

tracer_def = cesm.trace_gas_tracers(case)
tracer_3d = [k for k in tracer_def]
varlist = ['CO2','CO2_OCN','theta','U','PS','Z3']

ds = cesm.open_casedata(case,'atm','cam.h0',varlist)

ds = ds.sel(time=slice('2016-01-15','2016-02-29'))
ds = ds.sel(lon=-65.+360.,lat=slice(-90,-30))
ds = cesm.convert_dataset(ds,case)

print('ds size {:0.2f}GB\n'.format(ds.nbytes / 1e9))
ds.info()
# Out:
# ds size 0.00GB
#
# xarray.Dataset {
# dimensions:
# 	ilev = 57 ;
# 	lat = 64 ;
# 	lev = 56 ;
# 	nbnd = 2 ;
# 	slat = 191 ;
# 	slon = 288 ;
# 	time = 45 ;
#
# variables:
# 	float32 CO2(time, lev, lat) ;
# 		CO2:mdims = 1 ;
# 		CO2:units = ppmv ;
# 		CO2:long_name = CO2 ;
# 		CO2:cell_methods = time: mean ;
# 	float64 P0() ;
# 		P0:long_name = reference pressure ;
# 		P0:units = Pa ;
# 	float64 ch4vmr(time) ;
# 		ch4vmr:long_name = ch4 volume mixing ratio ;
# 	float64 co2vmr(time) ;
# 		co2vmr:long_name = co2 volume mixing ratio ;
# 	float64 f11vmr(time) ;
# 		f11vmr:long_name = f11 volume mixing ratio ;
# 	float64 f12vmr(time) ;
# 		f12vmr:long_name = f12 volume mixing ratio ;
# 	float64 gw(lat) ;
# 		gw:long_name = gauss weights ;
# 	float64 hyai(ilev) ;
# 		hyai:long_name = hybrid A coefficient at layer interfaces ;
# 	float64 hyam(lev) ;
# 		hyam:long_name = hybrid A coefficient at layer midpoints ;
# 	float64 hybi(ilev) ;
# 		hybi:long_name = hybrid B coefficient at layer interfaces ;
# 	float64 hybm(lev) ;
# 		hybm:long_name = hybrid B coefficient at layer midpoints ;
# 	float64 ilev(ilev) ;
# 		ilev:long_name = hybrid level at interfaces (1000*(A+B)) ;
# 		ilev:units = hPa ;
# 		ilev:positive = down ;
# 		ilev:standard_name = atmosphere_hybrid_sigma_pressure_coordinate ;
# 		ilev:formula_terms = a: hyai b: hybi p0: P0 ps: PS ;
# 	float64 lat(lat) ;
# 		lat:long_name = latitude ;
# 		lat:units = degrees_north ;
# 	float64 lev(lev) ;
# 		lev:long_name = hybrid level at midpoints (1000*(A+B)) ;
# 		lev:units = hPa ;
# 		lev:positive = down ;
# 		lev:standard_name = atmosphere_hybrid_sigma_pressure_coordinate ;
# 		lev:formula_terms = a: hyam b: hybm p0: P0 ps: PS ;
# 	float64 lon() ;
# 		lon:long_name = longitude ;
# 		lon:units = degrees_east ;
# 	float64 n2ovmr(time) ;
# 		n2ovmr:long_name = n2o volume mixing ratio ;
# 	int32 nbdate() ;
# 		nbdate:long_name = base date (YYYYMMDD) ;
# 	int32 ndbase() ;
# 		ndbase:long_name = base day ;
# 	int32 ndcur(time) ;
# 		ndcur:long_name = current day (from base day) ;
# 	int32 nlon(lat) ;
# 		nlon:long_name = number of longitudes ;
# 	int32 nscur(time) ;
# 		nscur:long_name = current seconds of current day ;
# 	float64 slat(slat) ;
# 		slat:long_name = staggered latitude ;
# 		slat:units = degrees_north ;
# 	float64 slon(slon) ;
# 		slon:long_name = staggered longitude ;
# 		slon:units = degrees_east ;
# 	float64 sol_tsi(time) ;
# 		sol_tsi:long_name = total solar irradiance ;
# 		sol_tsi:units = W/m2 ;
# 	object time(time) ;
# 		time:long_name = time ;
# 		time:units = days since 2005-01-01 00:00:00 ;
# 		time:calendar = gregorian ;
# 		time:bounds = time_bnds ;
# 	float64 time_bnds(time, nbnd) ;
# 		time_bnds:long_name = time interval endpoints ;
# 	float64 w_stag(slat) ;
# 		w_stag:long_name = staggered latitude weights ;
# 	int32 wnummax(lat) ;
# 		wnummax:long_name = cutoff Fourier wavenumber ;
# 	float32 CO2_OCN(time, lev, lat) ;
# 		CO2_OCN:mdims = 1 ;
# 		CO2_OCN:units = ppmv ;
# 		CO2_OCN:long_name = CO2_OCN ;
# 		CO2_OCN:cell_methods = time: mean ;
# 	float64 theta(time, lev, lat) ;
# 		theta:long_name = Potential temperature ;
# 		theta:units = K ;
# 	float32 U(time, lev, lat) ;
# 		U:mdims = 1 ;
# 		U:units = m/s ;
# 		U:long_name = Zonal wind ;
# 		U:cell_methods = time: mean ;
# 	float32 PS(time, lat) ;
# 		PS:units = Pa ;
# 		PS:long_name = Surface pressure ;
# 		PS:cell_methods = time: mean ;
# 	float32 Z3(time, lev, lat) ;
# 		Z3:mdims = 1 ;
# 		Z3:units = m ;
# 		Z3:long_name = Geopotential Height (above sea level) ;
# 		Z3:cell_methods = time: mean ;
#
# // global attributes:
# }CPU times: user 1min 6s, sys: 5.5 s, total: 1min 11s
# Wall time: 2min 13s

# %%
dsp = cam.pres_hybrid(ds)
dsp = cam.remap_vertical_coord(dsp.Pm,*[dsp[v] for v in varlist+['Pm']])
dsp
# Out:
# interpolating CO2
# /glade/work/mclong/miniconda3/envs/analysis/lib/python3.7/site-packages/metpy/xarray.py:436: MetpyDeprecationWarning: The log_interp function was deprecated in version 0.9. This function has been moved to metpy.interpolate and renamed log_interpolate_1d.
#   return func(*args, **kwargs)
# /glade/work/mclong/miniconda3/envs/analysis/lib/python3.7/site-packages/metpy/interpolate/one_dimension.py:138: UserWarning: Interpolation point out of data bounds encountered
#   warnings.warn('Interpolation point out of data bounds encountered')
# interpolating CO2_OCN
# interpolating theta
# interpolating U
# interpolating Z3
# interpolating Pm
# <xarray.Dataset>
# Dimensions:  (lat: 64, plev: 59, time: 45)
# Coordinates:
#   * time     (time) object 2016-01-15 12:00:00 ... 2016-02-28 12:00:00
#   * lat      (lat) float64 -90.0 -89.06 -88.12 -87.17 ... -32.51 -31.57 -30.63
#     lon      float64 295.0
#   * plev     (plev) float64 50.0 100.0 150.0 ... 1.01e+03 1.015e+03 1.02e+03
# Data variables:
#     CO2      (time, plev, lat) float64 388.8 388.5 388.2 388.0 ... nan nan nan
#     CO2_OCN  (time, plev, lat) float64 -4.458 -4.374 -4.289 ... nan nan nan
#     theta    (time, plev, lat) float64 554.2 553.7 553.5 553.2 ... nan nan nan
#     U        (time, plev, lat) float64 4.496 3.763 3.064 2.499 ... nan nan nan
#     Z3       (time, plev, lat) float64 2.062e+04 2.063e+04 2.063e+04 ... nan nan
#     Pm       (time, plev, lat) float64 50.12 50.12 50.12 50.12 ... nan nan nan
#     PS       (time, lat) float32 dask.array<shape=(45, 64), chunksize=(3, 64)>

# %%
dsp.Pm.isel(plev=-1).plot()

# %%
import plot_tools
v = 'CO2_OCN'

fig = plt.figure(figsize=(6,4))
ax = fig.add_axes([0.1,0.1,0.75,0.75])

#ax.minorticks_on()
#ax.tick_params(which='major',direction='out',width=1,  length=6)
#ax.tick_params(which='minor',direction='out',width=0.5,length=4)

cf = ax.contourf(dsp.lat, dsp.plev, dsp[v].mean(dim='time'),
                 levels=np.arange(-12,-7.2,0.2),
                 cmap = 'RdYlBu_r',
                 extend='both')

cs = ax.contour(dsp.lat, dsp.plev, dsp.U.mean(dim='time'),
                 levels=np.arange(-40,42.5,2.5),
                 colors = 'gray',
                 linewi = 0.5)

cs = ax.contour(dsp.lat, dsp.plev, dsp.theta.mean(dim='time'),
                 levels = np.arange(280.,360.,10),
                 colors = 'black',
                 linewi = 0.1)

cs.levels = [plot_tools.contour_label_format(val) for val in cs.levels]
fmt = '%r'
lb = plt.clabel(cs, fontsize=8,
                inline = True,
                fmt=fmt)
    
cbax = fig.add_axes([0.87,0.1,0.03,0.75])
cb = plt.colorbar(cf,cax=cbax)
cb.set_label('['+dsp[v].attrs['units']+']')

ax.set_xlim([-90.,-35.])
ax.set_ylim([dsp.plev[-1], 200.])

ax.set_xlabel('Latitude [$^\circ$N]')
ax.set_ylabel('Pressure [hPa]')
# Out:
# /glade/work/mclong/miniconda3/envs/analysis/lib/python3.7/site-packages/xarray/core/nanops.py:159: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis=axis, dtype=dtype)
# /glade/work/mclong/miniconda3/envs/analysis/lib/python3.7/site-packages/matplotlib/contour.py:1000: UserWarning: The following kwargs were not used by contour: 'linewi'
#   s)
# Text(0, 0.5, 'Pressure [hPa]')

# %%
geopotential_height_levels = xr.DataArray(
        np.array([ 42482.4296875,40789.765625,39157.46875,
                   37586.35546875,36074.7578125,34620.71875,
                   33221.05078125,31872.421875,30571.47265625,
                   29308.29492188,28075.45507812,26870.96875,
                   25694.5390625,24545.7109375,23423.09570312,
                   22326.65625,21252.5234375,20197.5078125,
                   19162.2578125,18146.8984375,17149.96484375,
                   16160.68554688,15167.20898438,14164.18066406,
                   13147.97851562,12116.08984375,11066.44824219,
                   9995.7109375,8912.61816406,8007.54882812,
                   7296.19238281,6637.14892578,6022.51513672,
                   5446.35351562,4903.87304688,4391.23974609,
                   3905.2668457,3443.27319336,3074.66967773,
                   2790.08691406,2513.83837891,2245.44848633,
                   1984.4967041,1755.61950684,1581.37988281,
                   1434.59033203,1290.03381348,1147.62548828,
                   1007.2913208,868.96289062,732.5602417,
                   598.00524902,465.22851562,334.16360474,
                   204.7640686,77.2164535]),
        dims=('zlev'),
        attrs={'long_name':'Geopotential height (above sea level)',
               'units':'m'})

dsh = cam.remap_vertical_coord(ds.Z3,*[ds[v] for v in varlist],new_levels=geopotential_height_levels)
dsh.zlev.values = dsh.zlev.values * 1e-3
dsh
# Out:
# interpolating CO2
# /glade/work/mclong/miniconda3/envs/analysis/lib/python3.7/site-packages/metpy/xarray.py:436: MetpyDeprecationWarning: The log_interp function was deprecated in version 0.9. This function has been moved to metpy.interpolate and renamed log_interpolate_1d.
#   return func(*args, **kwargs)
# /glade/work/mclong/miniconda3/envs/analysis/lib/python3.7/site-packages/metpy/interpolate/one_dimension.py:148: UserWarning: Interpolation point out of data bounds encountered
#   warnings.warn('Interpolation point out of data bounds encountered')
# interpolating CO2_OCN
# interpolating theta
# interpolating U
# interpolating Z3
# <xarray.Dataset>
# Dimensions:  (lat: 64, time: 45, zlev: 56)
# Coordinates:
#   * time     (time) object 2016-01-15 12:00:00 ... 2016-02-28 12:00:00
#   * lat      (lat) float64 -90.0 -89.06 -88.12 -87.17 ... -32.51 -31.57 -30.63
#     lon      float64 295.0
#   * zlev     (zlev) float64 42.48 40.79 39.16 37.59 ... 0.3342 0.2048 0.07722
# Data variables:
#     CO2      (time, zlev, lat) float64 381.7 381.6 381.6 381.6 ... nan nan nan
#     CO2_OCN  (time, zlev, lat) float64 -2.34 -2.338 -2.336 ... nan nan nan
#     theta    (time, zlev, lat) float64 1.527e+03 1.528e+03 1.529e+03 ... nan nan
#     U        (time, zlev, lat) float64 0.2213 -0.3875 -0.9917 ... nan nan nan
#     Z3       (time, zlev, lat) float64 4.249e+04 4.249e+04 4.249e+04 ... nan nan
#     PS       (time, lat) float32 dask.array<shape=(45, 64), chunksize=(3, 64)>

# %%
v = 'CO2_OCN'

fig = plt.figure(figsize=(6,4))
ax = fig.add_axes([0.1,0.1,0.75,0.75])
ax.set_facecolor('darkgray')
#ax.minorticks_on()
#ax.tick_params(which='major',direction='out',width=1,  length=6)
#ax.tick_params(which='minor',direction='out',width=0.5,length=4)

cf = ax.contourf(dsh.lat, dsh.zlev, dsh[v].mean(dim='time'),
                 levels=np.arange(-10.5,-8.2,0.1),
                 cmap = cmocean.cm.thermal,
                 extend='both')

cs = ax.contour(dsh.lat, dsh.zlev, dsh.U.mean(dim='time'),
                 levels=np.arange(-40,42.5,2.5),
                 colors = 'gray',
                 linewi = 0.5)

cs = ax.contour(dsh.lat, dsh.zlev, dsh.theta.mean(dim='time'),
                 levels = np.arange(280.,360.,10),
                 colors = 'black',
                 linewi = 0.1)

cs.levels = [plot_tools.contour_label_format(val) for val in cs.levels]
fmt = '%r'
lb = plt.clabel(cs, fontsize=8,
                inline = True,
                fmt=fmt)

cbax = fig.add_axes([0.87,0.1,0.03,0.75])
cb = plt.colorbar(cf,cax=cbax)
cb.set_label('['+dsh[v].attrs['units']+']')

ax.set_xlim([-90.,-35.])
ax.set_ylim([0., 12.])

ax.set_xlabel('Latitude [$^\circ$N]')
ax.set_ylabel('Altitude [km]')


waypoints = {'PSA':[-64.7667, 0.5],
             'SPO': [-89., 3.4]}

for name, xy in waypoints.items():    
    ax.plot(xy[0], xy[1],'*',markersize=10, color='w')
    if 'PSA' in name:
        t = ax.text(xy[0]+1, xy[1]+0.1, name, fontweight='bold', fontsize=15, color='w')
    elif 'SPO' in name:
        t = ax.text(xy[0]+1, xy[1]+0.1, name, fontweight='bold', fontsize=15, color='w')
    else:
        continue


plt.savefig(os.path.join(diro['fig'],'psa-spo-locator-yz-co2-theta-U.pdf'),dpi=300,bbox_inches='tight',
           transparent=False)
