# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import cartopy
import cartopy.crs as ccrs


from config_calc import *
import grid_tools

from collections import OrderedDict

import cesm_orcas_sci as cesm
import cam
import gv
import metpy.calc as mcalc

import colorbrewer

import statsmodels.api as sm
from scipy import stats
# Out:
# /Users/mclong/Dropbox/miniconda2/envs/py2/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
case = 'bgeos5.B20TRC5CN.f09_g16.BPRD_orcas_sci.004'
tracer_def = cesm.trace_gas_tracers(case)
tracer_3d = [k for k in tracer_def]
varlist = ['Z3','Q','PS','PBLH','T','U','V','U10','PSL','OMEGA']+tracer_3d

diri = os.path.join(dataroot,'orcas','cesm_flight_data')


model_files = [os.path.join(diri,'.'.join([case,os.path.basename(f)])) 
              for f in gv.flight_file]
ds = xr.open_mfdataset(model_files)

case = 'bgeos5.B20TRC5CN.f09_g16.BPRD_orcas_sci.004a'
model_files = [os.path.join(diri,'.'.join([case,os.path.basename(f)])) 
              for f in gv.flight_file]

dsa = xr.open_mfdataset(model_files)

ds.info()
# Out:
# xarray.Dataset {
# dimensions:
# 	time = 34205 ;
#
# variables:
# 	datetime64[ns] time(time) ;
# 	float64 O2_OCN(time) ;
# 		O2_OCN:units = per meg ;
# 		O2_OCN:long_name = O2_OCN ;
# 	float64 CO2_T09k(time) ;
# 		CO2_T09k:units = ppmv ;
# 		CO2_T09k:long_name = Takahashi (Dec x -150%) ;
# 	float64 aO2_GKA(time) ;
# 		aO2_GKA:units = per meg ;
# 		aO2_GKA:long_name = GK2001 (abiotic) ;
# 	float64 CO2_C15O(time) ;
# 		CO2_C15O:units = ppmv ;
# 		CO2_C15O:long_name = CT2015 (ocean) ;
# 	float64 CO2_LND(time) ;
# 		CO2_LND:units = ppmv ;
# 		CO2_LND:long_name = CO2_LND ;
# 	float64 U10(time) ;
# 		U10:units = m/s ;
# 		U10:long_name = 10m wind speed ;
# 		U10:cell_methods = time: mean ;
# 	float64 CO2_T09(time) ;
# 		CO2_T09:units = ppmv ;
# 		CO2_T09:long_name = Takahashi (2009) ;
# 	float64 PS(time) ;
# 		PS:units = hPa ;
# 		PS:long_name = Surface pressure ;
# 		PS:cell_methods = time: mean ;
# 	float64 CO2_T09b(time) ;
# 		CO2_T09b:units = ppmv ;
# 		CO2_T09b:long_name = Takahashi (Jan x +50%) ;
# 	float64 CO2_T09c(time) ;
# 		CO2_T09c:units = ppmv ;
# 		CO2_T09c:long_name = Takahashi (Dec x +25%) ;
# 	float64 CO2_T09d(time) ;
# 		CO2_T09d:units = ppmv ;
# 		CO2_T09d:long_name = Takahashi (Jan x +25%) ;
# 	float64 CO2_T09e(time) ;
# 		CO2_T09e:units = ppmv ;
# 		CO2_T09e:long_name = Takahashi (Dec x -25%) ;
# 	float64 CO2_T09f(time) ;
# 		CO2_T09f:units = ppmv ;
# 		CO2_T09f:long_name = Takahashi (Jan x -25%) ;
# 	float64 CO2_T09g(time) ;
# 		CO2_T09g:units = ppmv ;
# 		CO2_T09g:long_name = Takahashi (Dec x -50%) ;
# 	float64 CO2_T09h(time) ;
# 		CO2_T09h:units = ppmv ;
# 		CO2_T09h:long_name = Takahashi (Jan x -50%) ;
# 	float64 CO2_T09i(time) ;
# 		CO2_T09i:units = ppmv ;
# 		CO2_T09i:long_name = Takahashi (Dec x -75%) ;
# 	float64 CO2_T09j(time) ;
# 		CO2_T09j:units = ppmv ;
# 		CO2_T09j:long_name = Takahashi (Jan x -75%) ;
# 	float64 CO2_CROF(time) ;
# 		CO2_CROF:units = ppmv ;
# 		CO2_CROF:long_name = CT-NRT (FF) ;
# 	float64 CO2_T09l(time) ;
# 		CO2_T09l:units = ppmv ;
# 		CO2_T09l:long_name = Takahashi (Jan x -150%) ;
# 	float64 CO2_OCN(time) ;
# 		CO2_OCN:units = ppmv ;
# 		CO2_OCN:long_name = CO2_OCN ;
# 	float64 CO2_CROT(time) ;
# 		CO2_CROT:units = ppmv ;
# 		CO2_CROT:long_name = CT-NRT (total) ;
# 	float64 Pm(time) ;
# 		Pm:long_name = Pressure (layer center) ;
# 		Pm:units = hPa ;
# 	float64 OMEGA(time) ;
# 		OMEGA:mdims = 1 ;
# 		OMEGA:units = Pa/s ;
# 		OMEGA:long_name = Vertical velocity (pressure) ;
# 		OMEGA:cell_methods = time: mean ;
# 	float64 CO2_L14C(time) ;
# 		CO2_L14C:units = ppmv ;
# 		CO2_L14C:long_name = Landschutzer (2014) ;
# 	float64 Z3(time) ;
# 		Z3:mdims = 1 ;
# 		Z3:units = m ;
# 		Z3:long_name = Geopotential Height (above sea level) ;
# 		Z3:cell_methods = time: mean ;
# 	float64 PBLH(time) ;
# 		PBLH:units = m ;
# 		PBLH:long_name = PBL height ;
# 		PBLH:cell_methods = time: mean ;
# 	float64 CO2_T09a(time) ;
# 		CO2_T09a:units = ppmv ;
# 		CO2_T09a:long_name = Takahashi (Dec x +50%) ;
# 	float64 CO2_CROO(time) ;
# 		CO2_CROO:units = ppmv ;
# 		CO2_CROO:long_name = CT-NRT (ocean) ;
# 	float64 Q(time) ;
# 		Q:mdims = 1 ;
# 		Q:units = kg/kg ;
# 		Q:long_name = Specific humidity ;
# 		Q:cell_methods = time: mean ;
# 	float64 U(time) ;
# 		U:mdims = 1 ;
# 		U:units = m/s ;
# 		U:long_name = Zonal wind ;
# 		U:cell_methods = time: mean ;
# 	float64 T(time) ;
# 		T:mdims = 1 ;
# 		T:units = K ;
# 		T:long_name = Temperature ;
# 		T:cell_methods = time: mean ;
# 	float64 V(time) ;
# 		V:mdims = 1 ;
# 		V:units = m/s ;
# 		V:long_name = Meridional wind ;
# 		V:cell_methods = time: mean ;
# 	float64 O2_GKA(time) ;
# 		O2_GKA:units = per meg ;
# 		O2_GKA:long_name = GK2001 ;
# 	float64 CO2_C15T(time) ;
# 		CO2_C15T:units = ppmv ;
# 		CO2_C15T:long_name = CT2015 (total) ;
# 	float64 CO2_CROL(time) ;
# 		CO2_CROL:units = ppmv ;
# 		CO2_CROL:long_name = CT-NRT (land) ;
# 	float64 CO2(time) ;
# 		CO2:units = ppmv ;
# 		CO2:long_name = CO2 ;
# 	float64 CO2_FFF(time) ;
# 		CO2_FFF:units = ppmv ;
# 		CO2_FFF:long_name = CO2_FFF ;
# 	float64 PSL(time) ;
# 		PSL:units = Pa ;
# 		PSL:long_name = Sea level pressure ;
# 		PSL:cell_methods = time: mean ;
# 	float64 IDL_T000(time) ;
# 		IDL_T000:units = years ;
# 		IDL_T000:long_name = Age of air ;
# 	float64 IDL_T001(time) ;
# 		IDL_T001:units = years ;
# 		IDL_T001:long_name = Age of air (Land, except Antarctic) ;
# 	float64 IDL_T002(time) ;
# 		IDL_T002:units = years ;
# 		IDL_T002:long_name = Age of air (Anarctica) ;
# 	float64 IDL_T003(time) ;
# 		IDL_T003:units = years ;
# 		IDL_T003:long_name = Age of air (Ocean 90N-30S) ;
# 	float64 IDL_T004(time) ;
# 		IDL_T004:units = years ;
# 		IDL_T004:long_name = Age of air (Ocean 30S-45S) ;
# 	float64 IDL_T005(time) ;
# 		IDL_T005:units = years ;
# 		IDL_T005:long_name = Age of air (Ocean 45S-60S) ;
# 	float64 IDL_T006(time) ;
# 		IDL_T006:units = years ;
# 		IDL_T006:long_name = Age of air (Ocean 60S-90S) ;
# 	float64 IDL_S005(time) ;
# 		IDL_S005:units = fraction ;
# 		IDL_S005:long_name = Ocean 45S-60S ;
# 	float64 IDL_S004(time) ;
# 		IDL_S004:units = fraction ;
# 		IDL_S004:long_name = Ocean 30S-45S ;
# 	float64 CO2_C15F(time) ;
# 		CO2_C15F:units = ppmv ;
# 		CO2_C15F:long_name = CT2015 (FF) ;
# 	float64 IDL_S006(time) ;
# 		IDL_S006:units = fraction ;
# 		IDL_S006:long_name = Ocean 60S-90S ;
# 	float64 IDL_S001(time) ;
# 		IDL_S001:units = fraction ;
# 		IDL_S001:long_name = Land (except Antarctic) ;
# 	float64 IDL_S003(time) ;
# 		IDL_S003:units = fraction ;
# 		IDL_S003:long_name = Ocean 90N-30S ;
# 	float64 IDL_S002(time) ;
# 		IDL_S002:units = fraction ;
# 		IDL_S002:long_name = Anarctica ;
# 	float64 CO2_C15L(time) ;
# 		CO2_C15L:units = ppmv ;
# 		CO2_C15L:long_name = CT2015 (land) ;
# 	float64 CO2_CRPO(time) ;
# 		CO2_CRPO:units = ppmv ;
# 		CO2_CRPO:long_name = CT-NRT (ocean,prior) ;
# 	float64 theta(time) ;
# 		theta:long_name = Potential temperature ;
# 		theta:units = K ;
# 	float64 Year(time) ;
# 		Year:units = Year ;
# 		Year:long_name = Year ;
# 	float64 flt(time) ;
# 		flt:long_name = Flight number ;
# 	timedelta64[ns] DOY(time) ;
# 		DOY:long_name = Day of year ;
# 	timedelta64[ns] UTC(time) ;
# 		UTC:long_name = seconds since midnight on UTC day of takeoff ;
# 	float64 n_prof(time) ;
#
# // global attributes:
# }

# %%
for v in ['CO2','CO2_OCN','CO2_LND','CO2_FFF','O2_OCN','Z3','U','PBLH','Q','PS']:    
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.set_title(v)
    ax.plot(ds[v],dsa[v],'.')
    ylm = ax.get_ylim()
    xlm = ax.get_xlim()
    ax.plot(xlm,xlm,'r-')
